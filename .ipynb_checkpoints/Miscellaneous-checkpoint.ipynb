# %% [markdown]
# # Miscellaneous

# %% [markdown]
# * Set operations
# * Linear Algebra
# * Differential Equations

# %% [markdown]
# * Optimization
# * Graphs (as in graph theory)
# * Data manipulation and statistics

# %% [markdown]
# ## Set oprations

# %%
A = Set(['a','b','c'])

# %%
B=Set([1,4,'a','c'])

# %%
C=Set(['a','c'])

# %%
# Union
A∪B

# %%
# Intersection
A∩B

# %%
# check membership of elements
'a'∈A, 1∈A

# %%
# check inclusions 
A⊆ B

# %%
C⊆ A

# %%
# set differences
setdiff(A,B)

# %%
setdiff(B,A)

# %%
setdiff(C,A)

# %%
A-B

# %%
import Base: -

# %%
-(a::Set,b::Set)=setdiff(a,b)

# %%
A-B

# %%
B-A

# %%
#@edit symdiff(A,B)

# %%
F= Set([[x for x ∈ A if ~(x ∈ B)]...,[x for x ∈ B if ~(x ∈ A)]... ])

# %%
symdiff(A,B)

# %%
A,B

# %% [markdown]
# # Linear Algebra
# Linear algebra functions in Julia are largely implemented by calling functions from [LAPACK](http://www.netlib.org/lapack/). Sparse factorizations call functions from [SuiteSparse](http://faculty.cse.tamu.edu/davis/suitesparse.html).

# %%
A = rand(1:10,3,3)

# %%
@show trace(A) 
@show det(A) 
transpose(A) # A'

# %%
Λ = eigvals(A)

# %%
P=eigvecs(A)

# %%
(A-Λ[3]eye(A))P[:,3]

# %%
A-P*diagm(Λ)/P

# %%
? /

# %%
A*inv(A)≈ eye(A)

# %%
invA=A\I

# %%
b=ones(size(A,1))

# %%
## solve A * x = b
x = A\b

# %%
A*x

# %% [markdown]
# # Differential Equations
# ### Exponential Growth
#
# This model says that the rate of change is proportional to the current value, and is this:
#
# $$ u' = au $$
#
# where we have a starting value $u(0)=u_0$. Let's say we put 1 dollar into Bitcoin which is increasing at a rate of $98\%$ per year. Then calling now $t=0$ and measuring time in years, our model is:
#
# $$ u' = 0.98u $$
#
# and $u(0) = 1.0$. We encode this into Julia by noticing that, in this setup, we match the general form when
#
# $$ f(u,t) = 0.98u $$
#
# with $ u_0 = 1.0 $. If we want to solve this model on a time span from `t=0.0` to `t=1.0`, then we define an `ODEProblem` by specifying this function `f`, this initial condition `u0`, and this time span as follows:

# %%
using DifferentialEquations

# %%
f(u,p,t) = 0.98u
u0 = 1.0
tspan = (0.0,1.0)
prob = ODEProblem(f,u0,tspan)
# Out:
# DiffEqBase.ODEProblem with uType Float64 and tType Float64. In-place: false
# timespan: (0.0, 1.0)
# u0: 1.0

# %%
sol = solve(prob)
# Out:
# retcode: Success
# Interpolation: specialized 4th order "free" interpolation
# t: 5-element Array{Float64,1}:
#  0.0
#  0.100425
#  0.352186
#  0.693443
#  1.0
# u: 5-element Array{Float64,1}:
#  1.0
#  1.10342
#  1.41219
#  1.97304
#  2.66446

# %% [markdown]
# and that's it: we have succesfully solved our first ODE!
#
# #### Analyzing the Solution
#
# Of course, the solution type is not interesting in and of itself. We want to understand the solution! The documentation page which explains in detail the functions for analyzing the solution is the [Solution Handling](http://docs.juliadiffeq.org/latest/basics/solution.html) page. Here we will describe some of the basics. You can plot the solution using the plot recipe provided by [Plots.jl](http://docs.juliaplots.org/latest/):

# %%
using Plots; gr()
plot(sol)

# %%
plot(sol,linewidth=5,title="Solution to the linear ODE with a thick line",
     xaxis="Time (t)",yaxis="u(t) (in μm)",label="Numerical Solution") # legend=false
plot!(sol.t, t->1.0*exp(0.98t),lw=3,ls=:dash,label="True Solution!")

# %% [markdown]
# # Optimization
# Using `JuMP.jl`
# 1. solve a suduko puzzle
# 2. find Chebyshev Center

# %% [markdown]
# Let's solve
# ![Sudoko](./sudoku.png)

# %% [markdown]
# ### Model
# (Andrew Bartlett, Timothy P. Chartier, Amy N. Langville, and Timothy D. Rankin, "Integer Programming Model for the Sudoku Problem," Convergence (May 2008))
# * Define $729=9\times 9 \times 9$ decision variables as
# $$x_{i,j,k}=\left\{\begin{array}{ll}
# 1 & \text{ if position }(i,j) \text{ of the Sudoku matrix contains the integer } k \\
# 0 & \text{ otherwise}
# \end{array}\right.
# $$
# For example, in the above puzzle, $x_{2,2,6} =1 $ and $x_{2,2,k\not=6} =0 $
# * Constraints
#     1. each integer appears once each row
#     $$\sum_{j=1}^9 x_{i,j,k}=1, \quad i\in 1, \cdots 9, \quad k\in 1, \cdots, 9$$
#     2. each integer appears once each column
#     $$\sum_{i=1}^9 x_{i,j,k}=1, \quad j\in 1, \cdots 9, \quad k\in 1, \cdots, 9$$
#     3. every position in matrix must be filled
#     $$\sum_{k=1}^9 x_{i,j,k}=1, \quad i\in 1, \cdots 9, \quad j\in 1, \cdots, 9$$
#     4. each integer appears once in each 3x3 square
#     $$\sum_{r=i}^{i+2}\sum_{s=j}^{j+2} x_{r,s,k}=1, \quad i\in 1,4,7, \quad j\in 1, 4, 7, \quad k \in 1,\cdots,9$$
#     5. keep the same initial values
#     $$ x_{i,j,k}=1, \quad \text{for all } (i,j,k) \in G, \text{where } G \text{ is a set of trilps that corresponds to the initial Sudoku}  $$
#     6. each variable is a Binary variable
#     $$x_{i,j,k} \in \{0,1\}$$
#
# __ So the problem is an integer (binary) linear program as follows__
#
# $$
#  \begin{array}{ll}
#      \max & 0 \\
#      \text{subject to} \\
#      &
#      \sum_{j=1}^9 x_{i,j,k}=1, \quad i\in 1, \cdots 9, \quad k\in 1, \cdots, 9\\
#      &
#      \sum_{i=1}^9 x_{i,j,k}=1, \quad j\in 1, \cdots 9, \quad k\in 1, \cdots, 9\\
#     &
#     \sum_{k=1}^9 x_{i,j,k}=1, \quad i\in 1, \cdots 9, \quad j\in 1, \cdots, 9\\
#     &
#     \sum_{r=i}^{i+2}\sum_{s=j}^{j+2} x_{r,s,k}=1, \quad i\in 1,4,7, \quad j\in 1, 4, 7, \quad k \in 1,\cdots,9 \\
#     &
#     x_{i,j,k}=1, \quad \text{for all } (i,j,k) \in G, \text{where } G \text{ is a set of trilps that corresponds to the initial Sudoku}  \\
#     &
#     x_{i,j,k} \in \{0,1\}
# \end{array}
# $$

# %%
# suduko
# solve 
using JuMP, Cbc
# JuMP is a modeling language

# %%
# Create a model
sudoku = Model(solver=CbcSolver())

# Create our variables
@variable(sudoku, x[i=1:9, j=1:9, k=1:9], Bin)
# Out:
# 9×9×9 Array{JuMP.Variable,3}:
# [:, :, 1] =
#  x[1,1,1]  x[1,2,1]  x[1,3,1]  x[1,4,1]  …  x[1,7,1]  x[1,8,1]  x[1,9,1]
#  x[2,1,1]  x[2,2,1]  x[2,3,1]  x[2,4,1]     x[2,7,1]  x[2,8,1]  x[2,9,1]
#  x[3,1,1]  x[3,2,1]  x[3,3,1]  x[3,4,1]     x[3,7,1]  x[3,8,1]  x[3,9,1]
#  x[4,1,1]  x[4,2,1]  x[4,3,1]  x[4,4,1]     x[4,7,1]  x[4,8,1]  x[4,9,1]
#  x[5,1,1]  x[5,2,1]  x[5,3,1]  x[5,4,1]     x[5,7,1]  x[5,8,1]  x[5,9,1]
#  x[6,1,1]  x[6,2,1]  x[6,3,1]  x[6,4,1]  …  x[6,7,1]  x[6,8,1]  x[6,9,1]
#  x[7,1,1]  x[7,2,1]  x[7,3,1]  x[7,4,1]     x[7,7,1]  x[7,8,1]  x[7,9,1]
#  x[8,1,1]  x[8,2,1]  x[8,3,1]  x[8,4,1]     x[8,7,1]  x[8,8,1]  x[8,9,1]
#  x[9,1,1]  x[9,2,1]  x[9,3,1]  x[9,4,1]     x[9,7,1]  x[9,8,1]  x[9,9,1]
#
# [:, :, 2] =
#  x[1,1,2]  x[1,2,2]  x[1,3,2]  x[1,4,2]  …  x[1,7,2]  x[1,8,2]  x[1,9,2]
#  x[2,1,2]  x[2,2,2]  x[2,3,2]  x[2,4,2]     x[2,7,2]  x[2,8,2]  x[2,9,2]
#  x[3,1,2]  x[3,2,2]  x[3,3,2]  x[3,4,2]     x[3,7,2]  x[3,8,2]  x[3,9,2]
# ...

# %%
for i = 1:9, j = 1:9  # Each row and each column
    # Sum across all the possible digits
    # One and only one of the digits can be in this cell, 
    # so the sum must be equal to one
    @constraint(sudoku, sum(x[i,j,k] for k=1:9) == 1)
end

# %%
for ind = 1:9  # Each row, OR each column
    for k = 1:9  # Each digit
        # Sum across columns (j) - row constraint
        @constraint(sudoku, sum(x[ind,j,k] for j=1:9) == 1)
        # Sum across rows (i) - column constraint
        @constraint(sudoku, sum(x[i,ind,k]for i=1:9) == 1)
    end
end

# %%
for i = 1:3:7, j = 1:3:7, k = 1:9
    # i is the top left row, j is the top left column
    # We'll sum from i to i+2, e.g. i=4, r=4, 5, 6
    @constraint(sudoku, sum(x[r,s,k]for r=i:i+2, s=j:j+2) == 1)
end

# %%
init_sol = [ 4 0 0 0 0 8 9 0 0;
             0 6 0 0 0 5 7 0 0;
             0 2 0 0 7 0 0 4 0;
             8 0 2 0 5 0 0 0 9;
             0 0 0 2 8 4 0 0 0;
             7 0 0 0 9 0 2 0 4;
             0 8 0 0 3 0 0 1 0;
             0 0 5 8 0 0 0 9 0;
             0 0 1 7 0 0 0 0 2]
for i = 1:9, j = 1:9
    # If the space isn't empty
    if init_sol[i,j] != 0
        # Then the corresponding variable for that digit
        # and location must be 1
        @constraint(sudoku, x[i,j,init_sol[i,j]] == 1)
    end
end

# %%
solve(sudoku)
# Out:
# :Optimal

# %%
# Extract the values of x
x_val = getvalue(x)
# Create a matrix to store the solution
sol = zeros(Int,9,9)  # 9x9 matrix of integers
for i in 1:9, j in 1:9, k in 1:9
    # Integer programs are solved as a series of linear programs
    # so the values might not be precisely 0 and 1. We can just
    # round them to the nearest integer to make it easier
    if round(x_val[i,j,k], RoundUp) == 1
        sol[i,j] = k
    end
end
# Display the solution
sol
# Out:
# 9×9 Array{Int64,2}:
#  4  1  7  3  2  8  9  6  5
#  3  6  9  4  1  5  7  2  8
#  5  2  8  9  7  6  3  4  1
#  8  4  2  6  5  7  1  3  9
#  1  9  3  2  8  4  5  7  6
#  7  5  6  1  9  3  2  8  4
#  9  8  4  5  3  2  6  1  7
#  2  7  5  8  6  1  4  9  3
#  6  3  1  7  4  9  8  5  2

# %% [markdown]
# ![Solution](sudoku_sol.png)

# %% [markdown]
# ## Chebyshev Center
# This model is drawn from section 4.3.1 of the book Convex Optimization by Boyd and Vandenberghe
#
# Given a polyhedron described as a set of hyperplanes, i.e.
# $$ P=\left\{x \in \mathbb{R}^n ∣ a_ix≤b_i, \;\; \text{for } i=1,2,\cdots, m\right\}, $$
# find the largest Euclidean ball that lies inside the polyhedron. The center of this ball is known as the __Chebyshev center__ of the polyhedron.
#
# This problem can be formulated a linear optimization problem. Let $x$ be the center of the ball, and $r$ be the radius of the ball. Our ball can then be expressed as
# $$ B=\left\{x+u∣‖u‖_2≤r\right\} $$
# and we can express the constraint that the ball lies in a halfspace as
# $$ a_ix≤b_i, \text{i.e.}$$
# $$ a_i(x+u)≤b_i \quad \forall u:‖u‖_2≤r$$
# We can then use the fact that
# $$ \sup \{a_i u \;\;|\;\; ‖u‖_2 ≤r \} =r‖a_i‖_2 $$
# to simplify that constraint to the linear equality
# $$ a_ix+r‖a_i‖_2≤b_i $$
# which allows us to express the problem as
# $$ \max r \\ \text{ subject to}\\\;\; a_i x+r‖a_i‖≤b_i, \text{for } i=1,2,\cdots, m $$

# %%
using JuMP, SCS

# %%
# Use a hyperplane representation of the polyhedron
# i.e. P = { x | Ax ≤ b }
m = 4
# Store LHS as vector-of-vectors
A = Vector{Float64}[
    [ 2, 1], [ 2,-1],
    [-1, 2], [-1,-2]]
b = ones(m)
M = Model(solver=SCSSolver())
@variable(M, r)
@variable(M, x[1:2])
@objective(M, Max, r)
@constraint(M, P[i=1:4], dot(A[i],x) + norm(A[i])*r <= b[i])
M
# Out:
# Maximization problem with:
#  * 4 linear constraints
#  * 3 variables
# Solver is SCS

# %%
# Solve with any available LP solver

solve(M)

# Where is the center?
print(getvalue(x),getvalue(r))
# Out:
# [-7.22897e-8, 4.55641e-14]0.4472143262162362----------------------------------------------------------------------------
# 	SCS v1.1.5 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 12
# eps = 1.00e-004, alpha = 1.80, max_iters = 20000, normalize = 1, scale = 5.00
# Variables n = 3, constraints m = 4
# Cones:	linear vars: 4
# Setup time: 4.04e-005s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0|4.58e+000 5.53e+000 1.83e-001 -3.58e+000 -5.40e+000 0.00e+000 3.59e-005
#     60|1.07e-006 1.40e-006 2.73e-007 -4.47e-001 -4.47e-001 8.27e-018 6.99e-005
# ----------------------------------------------------------------------------
# Status: Solved
# ...

# %%
# Use Gadfly to display the solution
using Gadfly
Gadfly.set_default_plot_size(8cm, 8cm)
# Plot lines over [-1.5, 1.5]
domain = linspace(-1, +1)
# Plot circle across all angles
θ = linspace(0,2π)
plot(
# a_1 x_1 + a_2 x_2 = b
# --> x_2 = (b - a_1 x_1)/a_2
[layer(x=domain,
       y=(b[i]-A[i][1]*domain)/A[i][2],
       Geom.line,
       Theme(line_width=2px,
             default_color=colorant"blue")) for i in 1:4]...,
# x_1' = x_1 + rθ
# x_2' = x_2 + rθ
layer(x=getvalue(x[1]) + getvalue(r)*cos(θ),
      y=getvalue(x[1]) + getvalue(r)*sin(θ),
      Geom.path,
      Theme(line_width=5px,
            default_color=colorant"red")),
Coord.Cartesian(ymin=-1,ymax=+1)
)
# Out:
# WARNING: cos(x::AbstractArray{T}) where T <: Number is deprecated, use cos.(x) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] cos(::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}) at .\deprecated.jl:57
#  [3] include_string(::String, ::String) at .\loading.jl:522
#  [4] include_string(::Module, ::String, ::String) at C:\Users\ITC\.julia\v0.6\Compat\src\Compat.jl:71
#  [5] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\ITC\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [6] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\ITC\.julia\v0.6\Compat\src\Compat.jl:385
#  [7] eventloop(::ZMQ.Socket) at C:\Users\ITC\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [8] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[9], in expression starting on line 8
# Plot(...)

# %% [markdown]
# # Variational Inequalities

# %%
using VariationalInequality
using JuMP

m = VIPModel()

@variable(m, x1)
@variable(m, x2)
@variable(m, x3)

@constraint(m, const1, x1^2 + 0.4x2^2 + 0.6x3^2 <= 1)

@mapping(m, F1, 2x1 + 0.2x1^3 - 0.5x2 + 0.1x3 - 4)
@mapping(m, F2, -0.5x1 + x2 + 0.1x2^3 + 0.5)
@mapping(m, F3, 0.5x1 - 0.2x2 + 2x3 - 0.5)

@innerproduct(m, [F1, F2, F3], [x1, x2, x3])

#= or
// @innerproduct(m, F1, x1)
// @innerproduct(m, F2, x2)
// @innerproduct(m, F3, x3)
=#

sol1, Fval1, gap1 = solveVIP(m, algorithm=:fixed_point, max_iter=1000, step_size=0.5)
@assert 0<= gap1 < 1e-6

println("x1 = ", sol1[x1] )
println("x2 = ", sol1[x2] )
println("x3 = ", sol1[x3] )
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# iteration    1: rel_err= 1.014102279052
# iteration    2: rel_err= 0.197335863869
# iteration    3: rel_err= 0.043257143582
# iteration    4: rel_err= 0.016253286213
# iteration    5: rel_err= 0.006017000269
# iteration    6: rel_err= 0.002217940740
# iteration    7: rel_err= 0.000816213934
# iteration    8: rel_err= 0.000300186526
# iteration    9: rel_err= 0.000110377298
# iteration   10: rel_err= 0.000040581864
# iteration   11: rel_err= 0.000014920070
# iteration   12: rel_err= 0.000005485356
# iteration   13: rel_err= 0.000002016680
# iteration   14: rel_err= 0.000000741427
# ...

# %% [markdown]
# # Graphs
# Using `LightGraphs.jl`

# %%
srand(2018)
# Out:
# MersenneTwister(UInt32[0x000007e2], Base.dSFMT.DSFMT_state(Int32[-202096972, 1073008071, 2126042476, 1072793678, -64266256, 1072791560, -862800465, 1073689841, -1825118558, 1073580158  …  1117634044, 1073654874, -1803952621, 1073214982, 870324007, 762330074, 800503355, 556564238, 382, 0]), [1.62993, 1.64372, 1.00152, 1.8496, 1.52489, 1.85122, 1.64171, 1.6295, 1.16678, 1.26194  …  1.59566, 1.91561, 1.0845, 1.82866, 1.65264, 1.94445, 1.63029, 1.19504, 1.33961, 1.70219], 382)

# %%
using LightGraphs, GraphPlot
# Out:
# INFO: Recompiling stale cache file C:\Users\ITC\.julia\lib\v0.6\CodecZlib.ji for module CodecZlib.
# INFO: Recompiling stale cache file C:\Users\ITC\.julia\lib\v0.6\LightGraphs.ji for module LightGraphs.
# INFO: Precompiling module GraphPlot.

# %%
G₁ = Graph(3) # graph with 3 vertices

# make a triangle
add_edge!(G₁, 1, 2)
add_edge!(G₁, 1, 3)
add_edge!(G₁, 2, 3)

gplot(G₁, nodelabel=1:3)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Nullable{Compose.UnitBox}(Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm)), Nullable{Compose.Rotation}(), Nullable{Compose.Mirror}(), List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Nullable{Compose.UnitBox}(), Nullable{Compose.Rotation}(), Nullable{Compose.Mirror}(), List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.868373cx, 0.15934cy), (0.868373cx, 0.940775cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measu
# ...

# %%
g= PathGraph(6)
# Out:
# {6, 5} undirected simple Int64 graph

# %%
nv(g)
# Out:
# 6

# %%
ne(g)
# Out:
# 5

# %%
gplot(g)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Nullable{Compose.UnitBox}(Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm)), Nullable{Compose.Rotation}(), Nullable{Compose.Mirror}(), List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Nullable{Compose.UnitBox}(), Nullable{Compose.Rotation}(), Nullable{Compose.Mirror}(), List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.150864cx, -0.948361cy), (-0.911965cx, -0.501917cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.M
# ...

# %%
add_edge!(g,1,6)
# Out:
# true

# %%
adjacency_matrix(g)
# Out:
# 6×6 SparseMatrixCSC{Int64,Int64} with 12 stored entries:
#   [2, 1]  =  1
#   [6, 1]  =  1
#   [1, 2]  =  1
#   [3, 2]  =  1
#   [2, 3]  =  1
#   [4, 3]  =  1
#   [3, 4]  =  1
#   [5, 4]  =  1
#   [4, 5]  =  1
#   [6, 5]  =  1
#   [1, 6]  =  1
#   [5, 6]  =  1

# %%
# metal plate
□ = Graph(4)
add_edge!(□, 1, 2)
add_edge!(□, 1, 3)
add_edge!(□, 2, 4)
add_edge!(□, 3, 4)

# airplane skeleton
skeleton = Graph(11)
add_edge!(skeleton, 1, 2)
add_edge!(skeleton, 2, 3)
add_edge!(skeleton, 3, 4)
add_edge!(skeleton, 4, 5)
add_edge!(skeleton, 3, 6)
add_edge!(skeleton, 3, 7)
add_edge!(skeleton, 3, 8)
add_edge!(skeleton, 3, 9)
add_edge!(skeleton, 9, 10)
add_edge!(skeleton, 9, 11)
display(gplot(□, NODESIZE=0.05, nodefillc="red", nodelabel=1:4))
display(gplot(skeleton, nodelabel=1:nv(skeleton)))
gplot(cartesian_product(□, skeleton))
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Nullable{Compose.UnitBox}(Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm)), Nullable{Compose.Rotation}(), Nullable{Compose.Mirror}(), List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Nullable{Compose.UnitBox}(), Nullable{Compose.Rotation}(), Nullable{Compose.Mirror}(), List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.997126cx, 0.345174cy), (-0.922561cx, -0.950083cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Me
# ...

# %% [markdown]
# ### Graph traversal
# refers to a process that traverses vertices of a graph following certain order (starting from user-input sources

# %%
# BreadthFirst
t1=bfs_tree(skeleton,9)
# Out:
# {11, 10} directed simple Int64 graph

# %%
gplot(t1, nodelabel=1:nv(skeleton), edgelabel=1:ne(skeleton))
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Nullable{Compose.UnitBox}(Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm)), Nullable{Compose.Rotation}(), Nullable{Compose.Mirror}(), List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Nullable{Compose.UnitBox}(), Nullable{Compose.Rotation}(), Nullable{Compose.Mirror}(), List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.616619cx, 0.122845cy), (0.926726cx, 0.19769cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measur
# ...

# %%
# DepthFirst
t2=dfs_tree(skeleton,4)
# Out:
# {11, 10} directed simple Int64 graph

# %%
vertices(t2)
# Out:
# 1:11

# %%
edges(t2)
# Out:
# SimpleEdgeIter 10

# %%
d = [i for i in edges(t2)]
# Out:
# 10-element Array{LightGraphs.SimpleGraphs.SimpleEdge{Int64},1}:
#  Edge 1 => 2
#  Edge 2 => 3
#  Edge 3 => 4
#  Edge 3 => 6
#  Edge 3 => 7
#  Edge 3 => 8
#  Edge 3 => 9
#  Edge 4 => 5
#  Edge 9 => 10
#  Edge 9 => 11

# %% [markdown]
# # Some Statistics
# using the package `JuliaDB`
# The data used in these examples are for some Saudi Companies stock matrket prices.

# %%
using JuliaDB

IndexedTables.set_show_compact!(false);

# %%
stocks = loadtable("saudiStocks"; filenamecol = :Ticker, indexcols = [:Ticker, :DATE])
# Out:
# Table with 11569 rows, 14 columns:
# Ticker     DATE        OPEN    HIGH    LOW     CLOSE   VOLUME     EX_DIVIDEND  SPLIT_RATIO  ADJ_OPEN  ADJ_HIGH  ADJ_LOW  ADJ_CLOSE  ADJ_VOLUME
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# "Alrajhi"  2007-01-06  193.25  194.0   189.25  192.5   1.54978e6  0.0          1.0          107.763   108.181   105.533  107.345    2.7792e6
# "Alrajhi"  2007-01-07  192.5   192.5   184.0   184.5   1.20201e6  0.0          1.0          107.345   107.345   102.605  102.884    2.15554e6
# "Alrajhi"  2007-01-08  183.75  183.75  178.75  180.75  749285.0   0.0          1.0          102.466   102.466   99.6775  100.793    1.34368e6
# "Alrajhi"  2007-01-09  180.5   182.25  179.25  181.5   780934.0   0.0          1.0          100.653   101.629   99.9563  101.211    1.40044e6
# ...

# %%
; wc -l saudiStocks/Alrajhi.csv
# Out:
# 2914 saudiStocks/Alrajhi.csv

# %%
stocks[2913].Ticker
# Out:
# "Alrajhi"

# %%
stocks[2914].Ticker
# Out:
# "RiyadBank"

# %% [markdown]
# ### let's save the data as a binary file

# %%
save(stocks,"stocks")
# Out:
# Table with 11569 rows, 14 columns:
# Ticker     DATE        OPEN    HIGH    LOW     CLOSE   VOLUME     EX_DIVIDEND  SPLIT_RATIO  ADJ_OPEN  ADJ_HIGH  ADJ_LOW  ADJ_CLOSE  ADJ_VOLUME
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# "Alrajhi"  2007-01-06  193.25  194.0   189.25  192.5   1.54978e6  0.0          1.0          107.763   108.181   105.533  107.345    2.7792e6
# "Alrajhi"  2007-01-07  192.5   192.5   184.0   184.5   1.20201e6  0.0          1.0          107.345   107.345   102.605  102.884    2.15554e6
# "Alrajhi"  2007-01-08  183.75  183.75  178.75  180.75  749285.0   0.0          1.0          102.466   102.466   99.6775  100.793    1.34368e6
# "Alrajhi"  2007-01-09  180.5   182.25  179.25  181.5   780934.0   0.0          1.0          100.653   101.629   99.9563  101.211    1.40044e6
# ...

# %% [markdown]
# Load the binary file. It is way faster than loading CSV

# %%
BinStocks=load("stocks")
# Out:
# Table with 11569 rows, 14 columns:
# Ticker     DATE        OPEN    HIGH    LOW     CLOSE   VOLUME     EX_DIVIDEND  SPLIT_RATIO  ADJ_OPEN  ADJ_HIGH  ADJ_LOW  ADJ_CLOSE  ADJ_VOLUME
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# "Alrajhi"  2007-01-06  193.25  194.0   189.25  192.5   1.54978e6  0.0          1.0          107.763   108.181   105.533  107.345    2.7792e6
# "Alrajhi"  2007-01-07  192.5   192.5   184.0   184.5   1.20201e6  0.0          1.0          107.345   107.345   102.605  102.884    2.15554e6
# "Alrajhi"  2007-01-08  183.75  183.75  178.75  180.75  749285.0   0.0          1.0          102.466   102.466   99.6775  100.793    1.34368e6
# "Alrajhi"  2007-01-09  180.5   182.25  179.25  181.5   780934.0   0.0          1.0          100.653   101.629   99.9563  101.211    1.40044e6
# ...

# %% [markdown]
# #### select STC prices only

# %%
stc = filter(x->x.Ticker=="STC", BinStocks)
# Out:
# Table with 2910 rows, 14 columns:
# Ticker  DATE        OPEN   HIGH   LOW    CLOSE  VOLUME     EX_DIVIDEND  SPLIT_RATIO  ADJ_OPEN  ADJ_HIGH  ADJ_LOW  ADJ_CLOSE  ADJ_VOLUME
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# "STC"   2007-01-06  83.0   83.75  83.0   83.5   335893.0   0.0          1.0          44.2155   44.615    44.2155  44.4818    6.30529e5
# "STC"   2007-01-07  83.5   83.5   82.25  82.5   350793.0   0.0          1.0          44.4818   44.4818   43.8159  43.9491    6.58499e5
# "STC"   2007-01-08  82.0   82.0   80.75  81.25  669443.0   0.0          1.0          43.6827   43.6827   43.0169  43.2832    1.25666e6
# "STC"   2007-01-09  81.25  81.5   80.75  81.25  423769.0   0.0          1.0          43.2832   43.4164   43.0169  43.2832    795487.0
# "STC"   2007-01-10  81.0   81.25  79.0   79.0   1.0481e6   0.0          1.0          43.15     43.2832   42.0846  42.0846    1.96746e6
# ...

# %%
stcPrices = select(stc, :CLOSE)
stcDates = map(r->r,select(stc,:DATE))
# Out:
# 2910-element Array{Date,1}:
#  2007-01-06
#  2007-01-07
#  2007-01-08
#  2007-01-09
#  2007-01-10
#  2007-01-14
#  2007-01-15
#  2007-01-16
#  2007-01-17
#  2007-01-20
#  2007-01-21
#  2007-01-22
#  2007-01-23
#  ⋮
#  2018-03-21
#  2018-03-22
#  2018-03-25
#  2018-03-26
#  2018-03-27
#  2018-03-28
#  2018-03-29
#  2018-04-01
#  2018-04-02
#  2018-04-03
#  2018-04-04
#  2018-04-05

# %% [markdown]
# ### Plot them now

# %%
using Plots
plotlyjs()
# Out:
# Plots.PlotlyJSBackend()

# %%
plot(stcDates,stcPrices)
# Out:
# <div id="1fb2bde5-cb9f-4afc-b4e6-b11687144927" class="plotly-graph-div"></div>
#
# <script>
#     (function() {
# ...

# %% [markdown]
# ## find its average and std

# %%
summarize((mean, std), BinStocks, :Ticker; select = :CLOSE)
# Out:
# Table with 4 rows, 3 columns:
# Ticker       mean     std
# ─────────────────────────────
# "Alrajhi"    71.7297  17.0586
# "RiyadBank"  26.2593  17.0505
# "STC"        55.6356  13.7848
# "Sabic"      98.9418  24.9673
